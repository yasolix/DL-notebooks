# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
os.stat(filename)
# Out:
# posix.stat_result(st_mode=33204, st_ino=16702422, st_dev=2066, st_nlink=1, st_uid=1000, st_gid=1000, st_size=31344016, st_atime=1496131169, st_mtime=1495699212, st_ctime=1495699212)

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
words[:5]
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term']

# %%
collections.Counter(words).most_common()[:5]
# Out:
# [('the', 1061396),
#  ('of', 593677),
#  ('and', 416629),
#  ('one', 411764),
#  ('in', 372201)]

# %%
# Least Common Words
collections.Counter(words).most_common()[:-5-1:-1]
# Out:
# [('bretthorst', 1),
#  ('bergey', 1),
#  ('spendable', 1),
#  ('sundgau', 1),
#  ('brokenbeat', 1)]

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data[:10]
# Out:
# [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
count[:10]
# Out:
# [['UNK', 418391],
#  ('the', 1061396),
#  ('of', 593677),
#  ('and', 416629),
#  ('one', 411764),
#  ('in', 372201),
#  ('a', 325873),
#  ('to', 316376),
#  ('zero', 264975),
#  ('nine', 250430)]

# %%
dictionary['fawn']
# Out:
# 45848

# %%
reverse_dictionary[45848]
reverse_dictionary[10]
# Out:
# 'two'

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'a', 'anarchism', 'as', 'originated', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.246334
# Nearest to s: tsarina, fireplace, kris, dried, stunning, tsuba, menno, mercilessly,
# Nearest to such: mccartney, inconsistently, waiter, burroughs, antiaircraft, flipping, rahul, catalytic,
# Nearest to are: ctbt, interquartile, weighs, expanses, speer, ngos, heathen, harboring,
# Nearest to not: filenames, shetland, adhesive, visa, redrawing, cogent, rucker, logie,
# Nearest to would: machina, nevi, harden, bulfinch, triumphant, classicist, inflammation, poetically,
# Nearest to states: handily, ship, jstor, smp, sidewise, seafloor, did, condition,
# Nearest to history: hani, medusa, ddo, owls, cynicism, holies, cavour, channel,
# Nearest to from: reporters, inexact, cheap, dukedom, macho, vulgate, intermarriage, abraxas,
# Nearest to united: amit, restriction, remission, hughes, opioid, telemann, rsha, francophonie,
# Nearest to with: congregationalists, crane, kublai, iridium, protesters, thirdly, waza, classroom,
# Nearest to have: chojn, edgar, blizzards, emmylou, environmentally, dtd, cotton, ephesians,
# Nearest to he: reconstructed, adour, brie, coining, gyula, gives, saccharomyces, unchanging,
# Nearest to four: handlebar, yeats, seismology, earnings, panoramas, brainwashing, guadalcanal, tat,
# Nearest to seven: posen, bifurcation, immolation, darkened, pelican, marwan, emulator, sundarbans,
# Nearest to nine: interlinked, unanimous, monoxide, outings, landing, saberhagen, euphemism, madeira,
# Nearest to be: minh, barter, adamantium, widget, tubing, mecha, nukem, transplants,
# Average loss at step 2000: 4.374746
# Average loss at step 4000: 3.867404
# Average loss at step 6000: 3.793366
# Average loss at step 8000: 3.687431
# Average loss at step 10000: 3.614912
# Nearest to s: his, and, corelli, fireplace, laying, lambasted, lemay, dalits,
# Nearest to such: well, mccartney, maduro, inconsistently, alles, scorpio, known, ref,
# Nearest to are: were, is, interquartile, have, rom, reed, emancipation, tortured,
# Nearest to not: it, annexed, adhesive, still, consigned, to, sdi, circumstance,
# Nearest to would: could, can, may, will, to, should, emcee, not,
# Nearest to states: handily, sidewise, jstor, ship, ahaz, did, peruvian, macau,
# Nearest to history: hani, owls, channel, satire, sullivan, holies, lip, medusa,
# Nearest to from: in, with, during, anger, accommodating, nonsignatory, sadler, harpsichord,
# Nearest to united: amit, first, hughes, incriminating, enjoyment, tasso, nicholson, dyeing,
# Nearest to with: in, for, remaining, between, through, from, by, skiing,
# Nearest to have: has, had, be, are, were, wavelength, mythological, kazaa,
# Nearest to he: it, they, who, she, there, sometimes, adour, tenant,
# Nearest to four: six, three, eight, five, seven, two, zero, nine,
# Nearest to seven: eight, six, nine, five, three, four, zero, two,
# Nearest to nine: eight, six, seven, five, zero, three, four, two,
# Nearest to be: have, is, barter, was, roderick, docks, intv, differentiability,
# Average loss at step 12000: 3.608414
# Average loss at step 14000: 3.574265
# Average loss at step 16000: 3.409980
# Average loss at step 18000: 3.457404
# Average loss at step 20000: 3.543360
# Nearest to s: laying, corelli, motor, unreadable, sasson, piecemeal, binaries, external,
# Nearest to such: well, these, known, inconsistently, mccartney, maduro, eugenio, scorpio,
# Nearest to are: were, is, have, mythological, zap, grainy, was, be,
# Nearest to not: they, never, also, usually, it, still, consigned, to,
# Nearest to would: could, can, may, will, should, must, to, does,
# Nearest to states: handily, ship, jstor, ahaz, histones, pentatonic, inferiority, donaghy,
# Nearest to history: channel, owls, hani, lip, wears, days, holies, satire,
# Nearest to from: in, into, anger, at, and, by, within, through,
# Nearest to united: incriminating, amit, enjoyment, hughes, bet, first, dyeing, radial,
# Nearest to with: in, between, by, thelma, for, vince, into, skiing,
# Nearest to have: had, has, be, were, are, umar, flush, metrizable,
# Nearest to he: it, she, who, they, there, soon, bbses, which,
# Nearest to four: three, seven, six, five, eight, nine, two, zero,
# Nearest to seven: eight, five, six, four, nine, three, zero, two,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to be: have, been, was, by, is, were, make, docks,
# Average loss at step 22000: 3.507580
# Average loss at step 24000: 3.487611
# Average loss at step 26000: 3.479483
# Average loss at step 28000: 3.482737
# Average loss at step 30000: 3.500131
# Nearest to s: his, laying, isbn, transcriptions, corelli, unreadable, vcjd, futility,
# Nearest to such: well, these, known, immediate, maduro, alles, inconsistently, mccartney,
# Nearest to are: were, is, have, be, zap, include, dumont, these,
# Nearest to not: still, sdi, they, usually, it, there, never, now,
# Nearest to would: could, can, will, may, should, must, does, might,
# Nearest to states: kingdom, inferiority, ship, jstor, handily, nations, histones, bottle,
# Nearest to history: channel, catholic, origins, list, owls, wears, reply, lip,
# Nearest to from: into, in, within, circumcisions, by, through, vers, of,
# Nearest to united: incriminating, amit, hughes, enjoyment, bet, rsha, dyeing, thirtieth,
# Nearest to with: between, in, through, for, when, thelma, by, demoness,
# Nearest to have: had, has, were, are, be, umar, rainey, refer,
# Nearest to he: it, she, they, who, there, soon, millimetres, slithy,
# Nearest to four: five, six, three, seven, eight, nine, two, one,
# Nearest to seven: eight, four, nine, five, six, three, zero, one,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to be: have, been, refer, are, were, was, is, go,
# Average loss at step 32000: 3.501356
# Average loss at step 34000: 3.495232
# Average loss at step 36000: 3.457219
# Average loss at step 38000: 3.308076
# Average loss at step 40000: 3.427174
# Nearest to s: his, vcjd, wraith, nolan, valuation, and, iterating, her,
# Nearest to such: well, known, these, including, defined, immediate, inconsistently, grammer,
# Nearest to are: were, is, have, be, while, include, including, these,
# Nearest to not: still, they, it, usually, consigned, never, now, lewin,
# Nearest to would: could, will, can, may, should, must, might, does,
# Nearest to states: kingdom, nations, reginald, inferiority, ship, bottle, histones, pentatonic,
# Nearest to history: list, owls, tonsure, channel, prewar, satire, origins, catholic,
# Nearest to from: in, through, into, malo, belshazzar, disengage, blankets, within,
# Nearest to united: amit, hughes, incriminating, bet, enjoyment, thirtieth, webs, assamese,
# Nearest to with: between, through, hinayana, for, by, in, wer, when,
# Nearest to have: had, has, were, be, are, rainey, acquiesced, refer,
# Nearest to he: it, she, they, who, there, i, soon, millimetres,
# Nearest to four: six, three, five, seven, eight, two, nine, zero,
# Nearest to seven: eight, five, six, nine, four, three, zero, two,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to be: have, been, is, intv, are, refer, were, was,
# Average loss at step 42000: 3.435170
# Average loss at step 44000: 3.449150
# Average loss at step 46000: 3.456320
# Average loss at step 48000: 3.353354
# Average loss at step 50000: 3.383481
# Nearest to s: whose, unreadable, isbn, corelli, conglomeration, dimer, starfish, lambasted,
# Nearest to such: well, these, known, immediate, many, defined, including, grammer,
# Nearest to are: were, is, have, zap, exist, be, include, these,
# Nearest to not: still, usually, now, sdi, almost, generally, who, they,
# Nearest to would: could, will, can, may, should, must, might, does,
# Nearest to states: kingdom, nations, reginald, inferiority, histones, bottle, elrond, ship,
# Nearest to history: list, tonsure, romero, planet, owls, prewar, capt, biograph,
# Nearest to from: during, into, in, through, after, across, taliesin, amazement,
# Nearest to united: hughes, amit, incriminating, thirtieth, stairs, ahmad, bet, stadt,
# Nearest to with: between, hinayana, energetics, when, in, congregationalists, hippies, sina,
# Nearest to have: had, has, were, be, are, refer, acquiesced, rainey,
# Nearest to he: she, it, they, who, there, soon, we, millimetres,
# Nearest to four: six, five, three, eight, seven, nine, two, zero,
# Nearest to seven: six, nine, eight, four, five, three, zero, two,
# Nearest to nine: eight, seven, six, four, three, five, zero, two,
# Nearest to be: have, been, was, were, become, being, are, is,
# Average loss at step 52000: 3.436152
# Average loss at step 54000: 3.427553
# Average loss at step 56000: 3.436362
# Average loss at step 58000: 3.396095
# Average loss at step 60000: 3.394816
# Nearest to s: isbn, whose, unreadable, nolan, lemay, invents, swimmers, corelli,
# Nearest to such: well, these, known, many, immediate, including, described, grammer,
# Nearest to are: were, is, have, including, include, be, exist, but,
# Nearest to not: still, usually, you, now, almost, generally, sdi, truk,
# Nearest to would: could, will, may, can, should, might, must, does,
# Nearest to states: kingdom, nations, reginald, inferiority, exiles, elrond, ritchie, parties,
# Nearest to history: list, philosophy, tonsure, universe, culture, hepatic, geography, maryam,
# Nearest to from: through, into, within, in, oligopoly, ennio, repudiating, anger,
# Nearest to united: amit, hughes, thirtieth, webs, bet, stadt, stairs, assamese,
# Nearest to with: between, in, by, hegemony, hinayana, into, oems, when,
# Nearest to have: has, had, were, are, be, acquiesced, refer, provide,
# Nearest to he: she, it, they, there, who, soon, millimetres, eventually,
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to seven: eight, nine, four, six, five, three, zero, one,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to be: been, have, was, are, is, were, become, refer,
# Average loss at step 62000: 3.239015
# Average loss at step 64000: 3.253971
# Average loss at step 66000: 3.407307
# Average loss at step 68000: 3.392686
# Average loss at step 70000: 3.362199
# Nearest to s: unreadable, whose, nolan, isbn, bergson, corelli, swimmers, the,
# Nearest to such: these, well, known, many, including, immediate, regarded, other,
# Nearest to are: were, have, include, is, be, although, including, these,
# Nearest to not: still, now, usually, generally, never, easily, almost, they,
# Nearest to would: will, could, may, can, should, might, must, does,
# Nearest to states: kingdom, nations, reginald, inferiority, kata, countries, elrond, exiles,
# Nearest to history: list, philosophy, tonsure, culture, hepatic, jolson, origins, capt,
# Nearest to from: through, into, within, anger, across, during, in, magyar,
# Nearest to united: supreme, amit, radial, thirtieth, hughes, bet, assamese, webs,
# Nearest to with: between, hinayana, without, in, skiing, emphasise, thelma, vince,
# Nearest to have: had, has, were, are, be, having, seem, refer,
# Nearest to he: she, it, they, there, soon, we, who, millimetres,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to seven: six, eight, four, nine, five, three, zero, one,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to be: been, become, is, were, was, being, by, are,
# Average loss at step 72000: 3.370100
# Average loss at step 74000: 3.350225
# Average loss at step 76000: 3.316394
# Average loss at step 78000: 3.352550
# Average loss at step 80000: 3.374072
# Nearest to s: isbn, nolan, byelorussian, whose, vcjd, menno, bradbury, microbial,
# Nearest to such: well, these, known, regarded, including, immediate, described, defined,
# Nearest to are: were, include, is, have, although, these, be, exist,
# Nearest to not: still, usually, generally, it, sdi, they, almost, often,
# Nearest to would: will, could, may, should, can, might, must, cannot,
# Nearest to states: nations, kingdom, reginald, parties, elrond, state, inferiority, ritchie,
# Nearest to history: list, origins, philosophy, derails, tonsure, maryam, terrence, collection,
# Nearest to from: through, into, across, in, during, eec, after, within,
# Nearest to united: supreme, census, amit, thirtieth, supernaturalism, assamese, constitution, radial,
# Nearest to with: between, in, hinayana, on, including, when, through, or,
# Nearest to have: had, has, be, are, were, refer, flush, rainey,
# Nearest to he: she, it, they, there, soon, who, we, millimetres,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to nine: eight, seven, five, six, four, three, zero, two,
# Nearest to be: been, have, become, easily, being, refer, remain, were,
# Average loss at step 82000: 3.406376
# Average loss at step 84000: 3.408293
# Average loss at step 86000: 3.394608
# Average loss at step 88000: 3.352396
# Average loss at step 90000: 3.365729
# Nearest to s: isbn, whose, his, unreadable, her, lemay, extinguisher, dimer,
# Nearest to such: well, known, these, certain, regarded, many, grammer, woefully,
# Nearest to are: were, is, include, have, these, contain, erick, although,
# Nearest to not: still, never, sdi, we, lewin, almost, they, squealer,
# Nearest to would: will, could, might, may, can, should, must, did,
# Nearest to states: nations, kingdom, ritchie, reginald, inferiority, elrond, exercising, kata,
# Nearest to history: list, philosophy, derails, origins, safavid, bundle, tonsure, collection,
# Nearest to from: into, through, amazement, across, between, during, under, in,
# Nearest to united: supreme, constitution, amit, radial, assamese, supernaturalism, thirtieth, census,
# Nearest to with: between, in, using, including, calamities, shehhi, without, into,
# Nearest to have: has, had, were, are, refer, be, provide, include,
# Nearest to he: she, they, it, there, who, soon, but, later,
# Nearest to four: six, seven, five, three, eight, two, nine, zero,
# Nearest to seven: eight, five, six, four, nine, three, zero, two,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to be: been, become, lead, refer, was, have, being, is,
# Average loss at step 92000: 3.396121
# Average loss at step 94000: 3.257330
# Average loss at step 96000: 3.358760
# Average loss at step 98000: 3.242012
# Average loss at step 100000: 3.357669
# Nearest to s: whose, his, isbn, nolan, lemay, her, ezra, extinguisher,
# Nearest to such: known, well, these, regarded, certain, defined, many, separate,
# Nearest to are: were, have, include, be, these, is, exist, expectancies,
# Nearest to not: never, still, almost, they, actually, generally, palettes, you,
# Nearest to would: could, will, may, might, can, should, must, cannot,
# Nearest to states: nations, kingdom, reginald, inferiority, elrond, kata, us, parties,
# Nearest to history: list, collection, selection, origins, derails, impending, philosophy, resources,
# Nearest to from: into, through, across, in, within, belshazzar, amazement, eec,
# Nearest to united: supreme, constitution, radial, supernaturalism, census, assamese, amit, webs,
# Nearest to with: between, using, including, shehhi, spoleto, by, congregationalists, viridian,
# Nearest to have: had, has, were, be, are, provide, require, refer,
# Nearest to he: she, it, they, there, soon, we, who, knightly,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to be: been, become, have, is, being, are, refer, yield,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
#https://github.com/hankcs/udacity-deep-learning/blob/master/5_word2vec.py

data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        # just for testing
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        # iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
#https://github.com/kcbighuge/tensorflow-deeplearning/blob/master/5_word2vec.ipynb
data_index = 0

# keep batch size
def gen_batch_cbow(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  assert batch_size >= span
  batch = np.ndarray(shape=(batch_size, span-1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=1)
  buffer.append(data[data_index:data_index+span])    
  #print buffer
  data_index = (data_index + 1) % len(data)
  ## loop through batch size and update batch, labels
  for i in range(batch_size):
    batch[i,0:bag_window] = buffer[0][0:bag_window] # grab words left of target
    labels[i] = buffer[0][bag_window]  # grab target
    batch[i,bag_window:] = buffer[0][bag_window+1:]  # grab words right of target
    buffer.append(data[data_index:data_index+span])  # gen next buffer
    #print buffer
    data_index = (data_index + 1) % len(data)
    
  return np.array(batch, dtype=np.int32), np.array(labels, dtype=np.int32)

batch, labels = gen_batch_cbow(batch_size=6, bag_window=2)
print(batch.shape, '\n----')

for i in range(2):
  print(batch[i], '->', labels[i, 0])
  for j in batch[i]:
    print(reverse_dictionary[j])
  print('->', reverse_dictionary[labels[i, 0]])
  print('-'*16)
# Out:
# (6, 4)
# ----
# [5239 3084    6  195] -> 12
# anarchism
# originated
# a
# term
# -> as
# ----------------
# [3084   12  195    2] -> 6
# originated
# as
# term
# of
# -> a
# ----------------

# %%
#Building CBOW

# %%
batch_size = 128
bag_window = 1 # How many words to consider left and right.
embedding_size = 128 # Dimension of the embedding vector.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
''' Use same validation examples as above
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.

valid_examples = np.array(random.sample(xrange(1,valid_window), valid_size))
'''
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2*bag_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))

  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Model.
  sum_embed = tf.reduce_mean(tf.nn.embedding_lookup(embeddings, train_dataset), 1)
  print(sum_embed.get_shape().as_list())
  

  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=sum_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# [128, 128]

# %%
#Running CBOW

# %%
import time 
num_steps = 100001  # 100001

t0 = time.time()
with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print("Initialized in {} seconds".format(time.time()-t0))
  print("="*16)
  average_loss = 0
  for step in xrange(num_steps):
    batch_data, batch_labels = gen_batch_cbow(batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, lz = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += lz
    if step % 5000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print("Average loss at step", step, ":", average_loss)
      print("-"*16) 
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 20000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 4 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = "Nearest to %s:" % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = "%s %s," % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# show how much time elapsed
print((time.time()-t0)/60., 'minutes elapsed')
# Out:
# WARNING:tensorflow:From <ipython-input-98-7a3718696bc7>:6: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized in 0.241204977036 seconds
# ================
# Average loss at step 0 : 7.31224441528
# ----------------
# Nearest to b: hazmi, chaco, achaeans, technische,
# Nearest to from: nine, autocephalous, nicks, dean,
# Nearest to state: marvelous, skeletal, erwin, ley,
# Nearest to was: inquire, opinions, rings, accompany,
# Nearest to had: consensus, persepolis, accredited, ets,
# Nearest to with: gutman, dominant, idealised, agrarian,
# Nearest to first: earth, rhodesia, staff, topol,
# Nearest to time: technicality, preserve, affray, hypoxia,
# Nearest to than: gassing, jonny, corelli, compositions,
# Nearest to other: astros, cadiz, protoscience, deakin,
# Nearest to he: heartbroken, kayak, fabled, prophet,
# Nearest to often: gradually, complementary, reckoning, parkinson,
# Nearest to states: tautology, highschool, orthonormal, gobind,
# Nearest to united: detainee, cult, longitudes, looters,
# Nearest to th: theophilus, fingernails, begining, metropolises,
# Nearest to about: zoos, cohorts, aquaria, indymedia,
# Average loss at step 5000 : 9.20506284598
# ----------------
# Average loss at step 10000 : 8.02201883805
# ----------------
# Average loss at step 15000 : 7.84995155597
# ----------------
# Average loss at step 20000 : 7.66522969368
# ----------------
# Nearest to b: d, hazmi, enforcing, finnegans,
# Nearest to from: into, through, ukrainian, holman,
# Nearest to state: popping, suda, inklings, colloquium,
# Nearest to was: is, has, had, were,
# Nearest to had: has, have, was, were,
# Nearest to with: between, wade, during, venetian,
# Nearest to first: earth, staff, obliterated, second,
# Nearest to time: hypoxia, year, way, affray,
# Nearest to than: or, bisexual, jonny, dowry,
# Nearest to other: cadiz, astros, snapping, woven,
# Nearest to he: it, she, they, who,
# Nearest to often: generally, sometimes, usually, also,
# Nearest to states: nations, gobind, slobodan, waldseem,
# Nearest to united: detainee, cult, looters, authentic,
# Nearest to th: eight, fingernails, ignacio, kato,
# Nearest to about: didn, allan, least, reconquest,
# Average loss at step 25000 : 7.57799172783
# ----------------
# Average loss at step 30000 : 7.49977292442
# ----------------
# Average loss at step 35000 : 7.24112655479
# ----------------
# Average loss at step 40000 : 7.32401634798
# ----------------
# Nearest to b: d, ribs, orchestras, susanna,
# Nearest to from: through, into, predictive, holman,
# Nearest to state: inklings, city, states, colloquium,
# Nearest to was: is, became, has, had,
# Nearest to had: have, has, were, was,
# Nearest to with: between, during, venetian, porto,
# Nearest to first: second, last, final, staff,
# Nearest to time: year, way, hypoxia, problem,
# Nearest to than: or, bisexual, weld, clanking,
# Nearest to other: different, many, others, deakin,
# Nearest to he: she, it, they, there,
# Nearest to often: generally, sometimes, usually, commonly,
# Nearest to states: nations, state, kingdom, manchester,
# Nearest to united: detainee, cult, largest, bias,
# Nearest to th: fingernails, third, overgrown, kato,
# Nearest to about: didn, tanya, allan, least,
# Average loss at step 45000 : 7.33352109456
# ----------------
# Average loss at step 50000 : 7.21082433335
# ----------------
# Average loss at step 55000 : 7.12819179547
# ----------------
# Average loss at step 60000 : 7.00147282434
# ----------------
# Nearest to b: d, susanna, orchestras, finnegans,
# Nearest to from: into, through, towards, holman,
# Nearest to state: states, inklings, accuser, city,
# Nearest to was: is, had, became, has,
# Nearest to had: has, have, was, were,
# Nearest to with: between, during, merlot, among,
# Nearest to first: second, last, next, final,
# Nearest to time: way, competitively, year, seifert,
# Nearest to than: or, weld, orchards, bisexual,
# Nearest to other: others, various, fewer, medieval,
# Nearest to he: she, it, they, who,
# Nearest to often: usually, sometimes, generally, commonly,
# Nearest to states: nations, kingdom, state, manchester,
# Nearest to united: detainee, bias, longitudes, cult,
# Nearest to th: third, fingernails, brancusi, rd,
# Nearest to about: didn, crop, tanya, hekate,
# Average loss at step 65000 : 7.02137909552
# ----------------
# Average loss at step 70000 : 6.85220093873
# ----------------
# Average loss at step 75000 : 6.83795507663
# ----------------
# Average loss at step 80000 : 7.02128962722
# ----------------
# Nearest to b: d, kryptonite, orchestras, p,
# Nearest to from: through, into, predictive, holman,
# Nearest to state: states, inklings, boulogne, wali,
# Nearest to was: is, became, has, were,
# Nearest to had: has, have, having, was,
# Nearest to with: between, during, leaving, towards,
# Nearest to first: last, second, next, third,
# Nearest to time: competitively, seifert, way, year,
# Nearest to than: or, orchards, vulcan, weld,
# Nearest to other: others, fewer, various, individual,
# Nearest to he: she, it, they, there,
# Nearest to often: usually, sometimes, commonly, frequently,
# Nearest to states: nations, state, kingdom, manchester,
# Nearest to united: detainee, longitudes, bias, progressives,
# Nearest to th: third, fingernails, rd, nd,
# Nearest to about: crop, allan, brewers, didn,
# Average loss at step 85000 : 6.81891844893
# ----------------
# Average loss at step 90000 : 6.86692821848
# ----------------
# Average loss at step 95000 : 6.768539251
# ----------------
# Average loss at step 100000 : 6.36450684142
# ----------------
# Nearest to b: d, lit, kryptonite, johnson,
# Nearest to from: through, inside, into, understated,
# Nearest to state: states, inklings, boulogne, accuser,
# Nearest to was: is, were, became, had,
# Nearest to had: has, have, having, was,
# Nearest to with: between, incurring, venetian, daemen,
# Nearest to first: last, second, next, third,
# Nearest to time: competitively, seifert, way, rags,
# Nearest to than: or, orchards, vulcan, unlike,
# Nearest to other: various, individual, others, fewer,
# Nearest to he: she, it, they, there,
# Nearest to often: usually, sometimes, generally, frequently,
# Nearest to states: nations, state, kingdom, manchester,
# Nearest to united: caribbean, city, progressives, detainee,
# Nearest to th: third, fourth, fingernails, bc,
# Nearest to about: kidneys, brewers, didn, allan,
# 3.50989233653 minutes elapsed

# %%
#Showing in 2D

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

# %%
words = [reverse_dictionary[i] for i in xrange(1, num_points+1)]
plot(two_d_embeddings, words)
